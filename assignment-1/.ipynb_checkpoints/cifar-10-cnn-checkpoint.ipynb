# %% [markdown]
# # CNN CIFAR-10 Classification with Keras - Assignment 1
#
# This notebook implements a **Convolutional Neural Network (CNN)** for the **CIFAR-10** image classification task.
#
# ## Goals
#
# - Load and preprocess the **CIFAR-10** dataset
# - Train a **CNN** using **Keras 3** with the **TensorFlow backend**
# - Evaluate performance on the test set
# - Visualize learning curves
# - Inspect predictions and class probabilities
# - Analyze misclassified images
# - Measure training time and parameter count
#
# ## Notes
#
# - CIFAR-10 images are **32x32 RGB** images with **10 classes**
# - This notebook is the **CNN** part of the project

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import time
import numpy as np
import matplotlib.pyplot as plt

import keras
from keras import layers

from keras.utils import to_categorical

from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
print("Keras version:", keras.__version__)
print("Backend:", keras.backend.backend())
# Out:
# Keras version: 3.13.2
# Backend: tensorflow

# %%
# Model / data parameters
class_names = [
    "airplane", "automobile", "bird", "cat", "deer",
    "dog", "frog", "horse", "ship", "truck"
]

num_classes = 10
input_shape = (32, 32, 3)

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
# Out:
# /home/valvoja/miniconda3/envs/keras/lib/python3.11/site-packages/keras/src/datasets/cifar.py:18: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   d = cPickle.load(f, encoding="bytes")

# %%
# Show a few sample images from the training set
plt.figure(figsize=(12, 6))

for i in range(12):
    plt.subplot(3, 4, i + 1)
    plt.imshow(x_train[i])
    plt.title(class_names[y_train[i][0]])
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Preprocessing
#
# We normalize the pixel values from `[0, 255]` to `[0, 1]` and apply one-hot encoding to the labels.

# %%
# Normalizing
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

#One hot encoding
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
y_true = np.argmax(y_test, axis=1) # For later use in evaluation

print("x_train:", x_train.shape)
print("y_train:", y_train.shape)
print("x_test:", x_test.shape)
# Out:
# x_train: (50000, 32, 32, 3)
# y_train: (50000, 10)
# x_test: (10000, 32, 32, 3)

# %%
augmenter = keras.Sequential([
    layers.RandomFlip("horizontal"),
#    layers.RandomTranslation(0.1, 0.1),
    layers.RandomRotation(0.03),
    layers.RandomZoom(0.08),
], name="data_augmentation")

augmenter
# Out:
# <Sequential name=data_augmentation, built=False>

# %% [markdown]
# ## CNN model
#
# This model includes:
# - 3 convolution blocks
# - batch normalization within each block
# - max pooling
# - dropout after each block to manage over- / underfitting (.20, .25, .25, .25)
# - a dense classifier head

# %%
inputs = keras.Input(shape=input_shape)

x = augmenter(inputs)

# Convolutional block 1
x = layers.Conv2D(32, (3, 3), padding="same", activation=None, use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Conv2D(32, (3, 3), padding="same", activation=None, use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Dropout(0.20)(x)

# Convolutional block 2
x = layers.Conv2D(64, (3, 3), padding="same", activation=None, use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Conv2D(64, (3, 3), padding="same", activation=None, use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Dropout(0.25)(x)

# Convolutional block 3
x = layers.Conv2D(128, (3, 3), padding="same", activation=None, use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Conv2D(128, (3, 3), padding="same", activation=None, use_bias=False)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Dropout(0.25)(x)

x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation=None)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation("relu")(x)
x = layers.Dropout(0.25)(x)

outputs = layers.Dense(num_classes, activation='softmax')(x)

model = keras.Model(inputs, outputs, name="cifar10_cnn")

# %%
model.summary()
# Out:
# Model: "cifar10_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_28 (InputLayer)     │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_90 (Conv2D)              │ (None, 32, 32, 32)     │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_105         │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_105 (Activation)     │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_91 (Conv2D)              │ (None, 32, 32, 32)     │         9,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_106         │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_106 (Activation)     │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_45 (MaxPooling2D) │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_60 (Dropout)            │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_92 (Conv2D)              │ (None, 16, 16, 64)     │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_107         │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_107 (Activation)     │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_93 (Conv2D)              │ (None, 16, 16, 64)     │        36,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_108         │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_108 (Activation)     │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_46 (MaxPooling2D) │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_61 (Dropout)            │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_94 (Conv2D)              │ (None, 8, 8, 128)      │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_109         │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_109 (Activation)     │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_95 (Conv2D)              │ (None, 8, 8, 128)      │       147,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_110         │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_110 (Activation)     │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_47 (MaxPooling2D) │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_62 (Dropout)            │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_15     │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_111         │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_111 (Activation)     │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_63 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 324,970 (1.24 MB)
#  Trainable params: 323,562 (1.23 MB)
#  Non-trainable params: 1,408 (5.50 KB)

# %%
model.compile(
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    optimizer=keras.optimizers.AdamW(
        learning_rate=1e-3,
        weight_decay=1e-4
    ),
    metrics=["accuracy"],
)

callbacks = [
    EarlyStopping(monitor="val_loss", patience=12, restore_best_weights=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, verbose=1)
]

# %% [markdown]
# ## Training
# The model was trained using the AdamW optimizer with a learning rate of **1e-3** and a weight decay of **1e-4**. AdamW was chosen after testing different learning rate and weight decay values, as this combination gave the best overall performance in the experiments.
#
# The loss function was categorical crossentropy with **label smoothing = 0.1**, which was used to reduce overconfident predictions and improve generalization.
#
# Training was monitored using `EarlyStopping` and `ReduceLROnPlateau`, both based on validation loss. Early stopping restored the best weights when validation performance stopped improving, while learning rate reduction helped the model continue training more carefully after progress slowed down.

# %%
# Training
batch_size = 64
epochs = 50

start_time = time.time()

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
    callbacks=callbacks
)

training_time = time.time() - start_time
print(f"Training time: {training_time:.2f} seconds")
# Out:
# Epoch 1/50
# E0000 00:00:1774805216.277293    2357 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/cifar10_cnn_1/dropout_60_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.4261 - loss: 1.7488 - val_accuracy: 0.4700 - val_loss: 1.7182 - learning_rate: 0.0010
# Epoch 2/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.5717 - loss: 1.4466 - val_accuracy: 0.5971 - val_loss: 1.3997 - learning_rate: 0.0010
# Epoch 3/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 31ms/step - accuracy: 0.6318 - loss: 1.3250 - val_accuracy: 0.6163 - val_loss: 1.3808 - learning_rate: 0.0010
# Epoch 4/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.6744 - loss: 1.2395 - val_accuracy: 0.6619 - val_loss: 1.2846 - learning_rate: 0.0010
# Epoch 5/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 31ms/step - accuracy: 0.7056 - loss: 1.1792 - val_accuracy: 0.6470 - val_loss: 1.3279 - learning_rate: 0.0010
# Epoch 6/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.7260 - loss: 1.1346 - val_accuracy: 0.7125 - val_loss: 1.1615 - learning_rate: 0.0010
# Epoch 7/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.7416 - loss: 1.0980 - val_accuracy: 0.6889 - val_loss: 1.2180 - learning_rate: 0.0010
# Epoch 8/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.7548 - loss: 1.0721 - val_accuracy: 0.7227 - val_loss: 1.1508 - learning_rate: 0.0010
# Epoch 9/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.7700 - loss: 1.0463 - val_accuracy: 0.7954 - val_loss: 0.9923 - learning_rate: 0.0010
# Epoch 10/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.7762 - loss: 1.0317 - val_accuracy: 0.7528 - val_loss: 1.0882 - learning_rate: 0.0010
# Epoch 11/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7885 - loss: 1.0076 - val_accuracy: 0.7683 - val_loss: 1.0426 - learning_rate: 0.0010
# Epoch 12/50
# 611/625 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7979 - loss: 0.9868
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.7955 - loss: 0.9918 - val_accuracy: 0.7758 - val_loss: 1.0306 - learning_rate: 0.0010
# Epoch 13/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.8153 - loss: 0.9478 - val_accuracy: 0.8029 - val_loss: 0.9728 - learning_rate: 5.0000e-04
# Epoch 14/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8222 - loss: 0.9336 - val_accuracy: 0.8258 - val_loss: 0.9119 - learning_rate: 5.0000e-04
# Epoch 15/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.8255 - loss: 0.9215 - val_accuracy: 0.8271 - val_loss: 0.9134 - learning_rate: 5.0000e-04
# Epoch 16/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.8290 - loss: 0.9163 - val_accuracy: 0.8192 - val_loss: 0.9218 - learning_rate: 5.0000e-04
# Epoch 17/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.8329 - loss: 0.9106 - val_accuracy: 0.8409 - val_loss: 0.8807 - learning_rate: 5.0000e-04
# Epoch 18/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.8373 - loss: 0.9018 - val_accuracy: 0.8255 - val_loss: 0.9138 - learning_rate: 5.0000e-04
# Epoch 19/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.8403 - loss: 0.8940 - val_accuracy: 0.8097 - val_loss: 0.9650 - learning_rate: 5.0000e-04
# Epoch 20/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8435 - loss: 0.8891
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.8435 - loss: 0.8888 - val_accuracy: 0.8199 - val_loss: 0.9286 - learning_rate: 5.0000e-04
# Epoch 21/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.8509 - loss: 0.8691 - val_accuracy: 0.8466 - val_loss: 0.8640 - learning_rate: 2.5000e-04
# Epoch 22/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.8553 - loss: 0.8572 - val_accuracy: 0.8445 - val_loss: 0.8658 - learning_rate: 2.5000e-04
# Epoch 23/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.8543 - loss: 0.8576 - val_accuracy: 0.8390 - val_loss: 0.8805 - learning_rate: 2.5000e-04
# Epoch 24/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.8577 - loss: 0.8543 - val_accuracy: 0.8530 - val_loss: 0.8543 - learning_rate: 2.5000e-04
# Epoch 25/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.8585 - loss: 0.8519 - val_accuracy: 0.8493 - val_loss: 0.8622 - learning_rate: 2.5000e-04
# Epoch 26/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.8604 - loss: 0.8501 - val_accuracy: 0.8556 - val_loss: 0.8481 - learning_rate: 2.5000e-04
# Epoch 27/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.8636 - loss: 0.8423 - val_accuracy: 0.8530 - val_loss: 0.8465 - learning_rate: 2.5000e-04
# Epoch 28/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8633 - loss: 0.8412 - val_accuracy: 0.8515 - val_loss: 0.8537 - learning_rate: 2.5000e-04
# Epoch 29/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.8658 - loss: 0.8379 - val_accuracy: 0.8550 - val_loss: 0.8515 - learning_rate: 2.5000e-04
# Epoch 30/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8664 - loss: 0.8365
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 31ms/step - accuracy: 0.8674 - loss: 0.8356 - val_accuracy: 0.8536 - val_loss: 0.8471 - learning_rate: 2.5000e-04
# Epoch 31/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.8721 - loss: 0.8239 - val_accuracy: 0.8517 - val_loss: 0.8505 - learning_rate: 1.2500e-04
# Epoch 32/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.8740 - loss: 0.8219 - val_accuracy: 0.8637 - val_loss: 0.8278 - learning_rate: 1.2500e-04
# Epoch 33/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.8731 - loss: 0.8198 - val_accuracy: 0.8549 - val_loss: 0.8469 - learning_rate: 1.2500e-04
# Epoch 34/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.8734 - loss: 0.8206 - val_accuracy: 0.8570 - val_loss: 0.8424 - learning_rate: 1.2500e-04
# Epoch 35/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8766 - loss: 0.8134
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.8759 - loss: 0.8150 - val_accuracy: 0.8601 - val_loss: 0.8354 - learning_rate: 1.2500e-04
# Epoch 36/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.8769 - loss: 0.8125 - val_accuracy: 0.8643 - val_loss: 0.8281 - learning_rate: 6.2500e-05
# Epoch 37/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 31ms/step - accuracy: 0.8783 - loss: 0.8112 - val_accuracy: 0.8651 - val_loss: 0.8277 - learning_rate: 6.2500e-05
# Epoch 38/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8799 - loss: 0.8053
# Epoch 38: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.8791 - loss: 0.8078 - val_accuracy: 0.8618 - val_loss: 0.8296 - learning_rate: 6.2500e-05
# Epoch 39/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8816 - loss: 0.8052 - val_accuracy: 0.8657 - val_loss: 0.8234 - learning_rate: 3.1250e-05
# Epoch 40/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.8780 - loss: 0.8068 - val_accuracy: 0.8683 - val_loss: 0.8173 - learning_rate: 3.1250e-05
# Epoch 41/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8810 - loss: 0.8060 - val_accuracy: 0.8622 - val_loss: 0.8273 - learning_rate: 3.1250e-05
# Epoch 42/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 31ms/step - accuracy: 0.8816 - loss: 0.8037 - val_accuracy: 0.8683 - val_loss: 0.8178 - learning_rate: 3.1250e-05
# Epoch 43/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.8810 - loss: 0.8032 - val_accuracy: 0.8684 - val_loss: 0.8165 - learning_rate: 3.1250e-05
# Epoch 44/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.8803 - loss: 0.8058 - val_accuracy: 0.8656 - val_loss: 0.8232 - learning_rate: 3.1250e-05
# Epoch 45/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.8816 - loss: 0.8026 - val_accuracy: 0.8645 - val_loss: 0.8250 - learning_rate: 3.1250e-05
# Epoch 46/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8840 - loss: 0.7976
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.8806 - loss: 0.8025 - val_accuracy: 0.8680 - val_loss: 0.8180 - learning_rate: 3.1250e-05
# Epoch 47/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.8828 - loss: 0.8012 - val_accuracy: 0.8670 - val_loss: 0.8173 - learning_rate: 1.5625e-05
# Epoch 48/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.8837 - loss: 0.7997 - val_accuracy: 0.8651 - val_loss: 0.8212 - learning_rate: 1.5625e-05
# Epoch 49/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8866 - loss: 0.7942
# Epoch 49: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.8829 - loss: 0.8004 - val_accuracy: 0.8673 - val_loss: 0.8188 - learning_rate: 1.5625e-05
# Epoch 50/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - accuracy: 0.8831 - loss: 0.8001 - val_accuracy: 0.8674 - val_loss: 0.8192 - learning_rate: 7.8125e-06
# Training time: 924.78 seconds

# %% [markdown]
# ## Evaluation
#
# Below are the following evaluation steps:
#
# - Training and validation loss and accuracy curves are plotted to visualize the training process.
# - Evaluation on the test set to get the final loss and accuracy.
# - Classification report to show precision, recall, and F1-score for each class.
# - Confusion matrix to visualize which classes are being confused with each other.
# - Misclassified image analysis
# - Prediction analysis

# %% [markdown]
# ### Learning curves
# The learning curves show how the training and validation loss and accuracy evolved over the epochs. This helps to understand if the model was overfitting, underfitting, or training well. This was a useful step during the experiments to find the right dropout values.

# %%
# Plot learning curves
plt.figure(figsize=(8, 5))
plt.plot(history.history["loss"], label="Training loss")
plt.plot(history.history["val_loss"], label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and validation loss")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(history.history["accuracy"], label="Training accuracy")
plt.plot(history.history["val_accuracy"], label="Validation accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Evaluation on test set

# %%
# Evaluate on test data
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"Test loss: {test_loss:.4f}")
print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# Test loss: 0.8359
# Test accuracy: 0.8612

# %% [markdown]
# Goals were 75-80% (realistic) or up to 82-85% (ambitious) accuracy on the test set. The final model achieved accuracy of around 86-87% depending on run, which is a fairly good result for a simple **CNN** on **CIFAR-10**.
# The loss is a little higher due to the use of label smoothing, which is expected.

# %% [markdown]
# ### Classification report
# The classification report helps to understand the performance of the model on each class.

# %%
# Make predictions on test set
y_prob = model.predict(x_test, verbose=0)
y_pred = np.argmax(y_prob, axis=1)

print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.89      0.88      0.89      1000
#   automobile       0.93      0.94      0.94      1000
#         bird       0.83      0.81      0.82      1000
#          cat       0.81      0.66      0.73      1000
#         deer       0.83      0.86      0.84      1000
#          dog       0.81      0.77      0.79      1000
#         frog       0.80      0.95      0.87      1000
#        horse       0.90      0.89      0.89      1000
#         ship       0.93      0.93      0.93      1000
#        truck       0.88      0.94      0.91      1000
#
#     accuracy                           0.86     10000
#    macro avg       0.86      0.86      0.86     10000
# weighted avg       0.86      0.86      0.86     10000

# %% [markdown]
# Performance was strongest for classes such as **automobile**, **truck**, **ship**, and **airplane**. While classes like **cat**, **dog**, **frog**, and **deer** had lower precision and recall, probably due to higher visual similarity and more complex features.

# %% [markdown]
# ### Confusion matrix
# The confusion matrix provides a detailed view of how the model is performing across all classes, showing which classes are being confused with each other.

# %%
# Confusion matrix
cm = confusion_matrix(y_true, y_pred)

fig, ax = plt.subplots(figsize=(9, 9))
ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=class_names
).plot(ax=ax, xticks_rotation=45, colorbar=False)

plt.title("Confusion matrix")
plt.show()

# %% [markdown]
# Once again it can be seen that most confusion occurs between visually similar classes, especially **cat vs dog**.

# %% [markdown]
# ### Prediction analysis
# One random test example from each true class is displayed together with predicted probabilities. This helps to understand how confident the model is in its predictions and to see examples of correct and incorrect classifications.

# %%
# Show one random example for each true label
indices = [
    np.random.choice(np.where(y_true == class_id)[0])
    for class_id in range(num_classes)
]

for idx in indices:
    fig, axes = plt.subplots(1, 2, figsize=(10, 3))

    axes[0].imshow(x_test[idx])
    axes[0].set_title(
        f"True: {class_names[y_true[idx]]}\nPred: {class_names[y_pred[idx]]}"
    )
    axes[0].axis("off")

    axes[1].bar(range(num_classes), y_prob[idx])
    axes[1].set_xticks(range(num_classes))
    axes[1].set_xticklabels(class_names, rotation=45, ha="right")
    axes[1].set_ylim(0, 1)
    axes[1].set_title("Predicted probabilities")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Misclassified image analysis
# To better understand the model's performance and weaknesses, we inspect a sample of test images that were classified incorrectly. This has helped reveal common error patterns, such as confusion between visually similar classes (usually **cat vs dog**).

# %%
# Analyze misclassified images
misclassified = np.where(y_pred != y_true)[0]
print("Number of misclassified test images:", len(misclassified))

n_show = min(12, len(misclassified))
plt.figure(figsize=(14, 10))
for i, idx in enumerate(misclassified[:n_show]):
    plt.subplot(3, 4, i + 1)
    plt.imshow(x_test[idx])
    plt.title(
        f"True: {class_names[y_true[idx]]}\nPred: {class_names[y_pred[idx]]}"
    )
    plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# Number of misclassified test images: 1388

# %% [markdown]
# ## Experiment summary
#
# The CNN model was improved through several test runs, starting from a simpler base model and gradually adding changes that improved performance.
#
# The first version was a basic CNN with one `Conv2D` layer per block and no batch normalization. The model was then improved by adding a second convolution layer to each block, batch normalization, dropout, and a smaller classifier section using `GlobalAveragePooling2D` instead of `Flatten`.
#
# The final model used three convolutional blocks with filter sizes **32 → 64 → 128**. Each block followed the pattern `Conv2D + BatchNorm + ReLU` twice, followed by max pooling and dropout. This gave better results than the earlier, simpler versions.
#
# Several regularization methods were tested during the experiments. Dropout had a large effect on performance, and finding suitable dropout values was one of the most important and time-consuming parts of the tuning process. With 50 epochs and a batch size of 64, one training run took around 15 minutes. Data augmentation also improved performance, especially random horizontal flipping and small random rotations. Random translations were tested as well, but they reduced performance and were left out of the final setup.
#
# Another useful change was replacing `Flatten` with `GlobalAveragePooling2D`, which reduced the number of parameters and kept the classifier section smaller.
#
# The optimizer was also tuned during the experiments. The model was first trained with the default **Adam** optimizer, and later **AdamW** was tested with different learning rate and weight decay values. The best results were achieved with **AdamW** using a learning rate of **1e-3** and a weight decay of **1e-4**.
#
# Overall, the final result was reached through repeated testing and gradual improvements rather than from a single training run. The experiments showed that model structure, dropout values, and data augmentation all had a clear impact on the final performance.

# %% [markdown]
# ## Model summary
#
# Final test results for the CNN model:
#
# - Test accuracy: **0.8612**
# - Test loss: **0.8359**
# - Total parameters: **324,970**
# - Trainable parameters: **323,562**
# - Training time: **924.78 s** (~15.4 min)

# %%
os.makedirs("models", exist_ok=True)
model.save("models/cifar10_cnn.keras")
print("Model saved as cifar10_cnn.keras")
# Out:
# Model saved as cifar10_cnn.keras

# %%
model = keras.models.load_model("models/cifar10_cnn.keras")
print("Model loaded: cifar10_cnn")
# Out:
# Model loaded: cifar10_cnn
