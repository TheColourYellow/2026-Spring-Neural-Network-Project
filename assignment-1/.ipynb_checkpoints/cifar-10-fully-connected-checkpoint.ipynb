# %%
import keras
from keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.models import Sequential
from keras.callbacks import EarlyStopping

import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# C:\Users\Patrik\anaconda3\envs\keras\Lib\site-packages\keras\src\datasets\cifar.py:18: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   d = cPickle.load(f, encoding="bytes")

# %%
"""
assert x_train.shape == (50000, 32, 32, 3)
assert x_test.shape == (10000, 32, 32, 3)
assert y_train.shape == (50000, 1)
assert y_test.shape == (10000, 1)
"""

# Normalizing
x_train=x_train/255
x_test=x_test/255

#One hot encoding
y_train=to_categorical(y_train,10)
y_test=to_categorical(y_test,10)

# %%
model = Sequential([
    Input(shape=(32, 32, 3)),
    Flatten(),
    Dense(256, activation='relu'),
    Dense(10, activation='softmax')
    ])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       786,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 789,258 (3.01 MB)
#  Trainable params: 789,258 (3.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    loss=keras.losses.CategoricalCrossentropy(),
    optimizer=keras.optimizers.Adam(),
    metrics=["accuracy"],
)

# %%
history = model.fit(x_train, y_train, batch_size=64, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.3187 - loss: 1.9173 - val_accuracy: 0.3599 - val_loss: 1.8037
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.3842 - loss: 1.7347 - val_accuracy: 0.3943 - val_loss: 1.7145
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.4105 - loss: 1.6627 - val_accuracy: 0.3965 - val_loss: 1.7086
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.4233 - loss: 1.6195 - val_accuracy: 0.4322 - val_loss: 1.6177
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.4352 - loss: 1.5897 - val_accuracy: 0.4345 - val_loss: 1.6009
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.4465 - loss: 1.5590 - val_accuracy: 0.4369 - val_loss: 1.5972
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.4570 - loss: 1.5332 - val_accuracy: 0.4303 - val_loss: 1.6014
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.4596 - loss: 1.5163 - val_accuracy: 0.4421 - val_loss: 1.5832
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.4699 - loss: 1.4978 - val_accuracy: 0.4481 - val_loss: 1.5555
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.4747 - loss: 1.4801 - val_accuracy: 0.4399 - val_loss: 1.5939

# %%
test_scores = model.evaluate(x_test, y_test, verbose=2)
print("Test loss:", test_scores[0])
print("Test accuracy:", test_scores[1])
# Out:
# 313/313 - 1s - 3ms/step - accuracy: 0.4443 - loss: 1.5758
# Test loss: 1.5758086442947388
# Test accuracy: 0.44429999589920044

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.grid()
plt.show()

# %%
model = Sequential([
    Input(shape=(32, 32, 3)),
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.1),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
    ])

# %%
model.compile(
    loss=keras.losses.CategoricalCrossentropy(),
    optimizer=keras.optimizers.Adam(),
    metrics=["accuracy"],
)

# %%
history = model.fit(x_train, y_train, batch_size=64, epochs=50, validation_split=0.2, verbose=0)

# %%
test_scores = model.evaluate(x_test, y_test, verbose=2)
print("Test loss:", test_scores[0])
print("Test accuracy:", test_scores[1])
# Out:
# 313/313 - 1s - 4ms/step - accuracy: 0.4925 - loss: 1.4319
# Test loss: 1.431902289390564
# Test accuracy: 0.4925000071525574

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.grid()
plt.show()

# %%
model = Sequential([
    Input(shape=(32, 32, 3)),
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.1),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.1),
    Dense(10, activation='softmax')
    ])

# %%
model.compile(
    loss=keras.losses.CategoricalCrossentropy(),
    optimizer=keras.optimizers.Adam(),
    metrics=["accuracy"],
)

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(x_train, y_train, epochs=500, batch_size=64, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.3004 - loss: 1.9532 - val_accuracy: 0.3574 - val_loss: 1.8114
# Epoch 2/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.3620 - loss: 1.7837 - val_accuracy: 0.3561 - val_loss: 1.7832
# Epoch 3/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.
500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.5151 - loss: 1.3585 - val_accuracy: 0.4868 - val_loss: 1.4260
# Epoch 31/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.5148 - loss: 1.3507 - val_accuracy: 0.4815 - val_loss: 1.4509
# Epoch 32/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.5178 - loss: 1.3506 - val_accuracy: 0.4842 - val_loss: 1.4485
# Epoch 33/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.5194 - loss: 1.3467 - val_accuracy: 0.4926 - val_loss: 1.4341
# Epoch 34/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.5236 - loss: 1.3389 - val_accuracy: 0.4925 - val_loss: 1.4452
# Epoch 35/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.5230 - loss: 1.3404 - val_accuracy: 0.4914 - val_loss: 1.4285
# Epoch 36/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.5279 - loss: 1.3254 - val_accuracy: 0.4903 - val_loss: 1.4401
# Epoch 37/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.5275 - loss: 1.3248 - val_accuracy: 0.4984 - val_loss: 1.4256
# Epoch 38/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.5254 - loss: 1.3236 - val_accuracy: 0.4810 - val_loss: 1.4504
# Epoch 39/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.5257 - loss: 1.3221 - val_accuracy: 0.4912 - val_loss: 1.4245
# Epoch 40/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.5291 - loss: 1.3135 - val_accuracy: 0.4889 - val_loss: 1.4461
# Epoch 41/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.5311 - loss: 1.3091 - val_accuracy: 0.4787 - val_loss: 1.4680
# Epoch 42/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.5322 - loss: 1.3091 - val_accuracy: 0.4950 - val_loss: 1.4282
# Epoch 43/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.5351 - loss: 1.3015 - val_accuracy: 0.4919 - val_loss: 1.4270
# Epoch 44/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.5339 - loss: 1.2969 - val_accuracy: 0.4889 - val_loss: 1.4363
# Epoch 45/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.5360 - loss: 1.2946 - val_accuracy: 0.4876 - val_loss: 1.4432
# Epoch 46/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.5384 - loss: 1.2909 - val_accuracy: 0.4860 - val_loss: 1.4564
# Epoch 47/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.5377 - loss: 1.2916 - val_accuracy: 0.4939 - val_loss: 1.4288
# Epoch 48/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.5382 - loss: 1.2861 - val_accuracy: 0.4790 - val_loss: 1.4710
# Epoch 49/500
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.5434 - loss: 1.2826 - val_accuracy: 0.4923 - val_loss: 1.4249

# %%
test_scores = model.evaluate(x_test, y_test, verbose=2)
print("Test loss:", test_scores[0])
print("Test accuracy:", test_scores[1])
# Out:
# 313/313 - 1s - 4ms/step - accuracy: 0.5027 - loss: 1.4053
# Test loss: 1.4053443670272827
# Test accuracy: 0.5026999711990356

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.grid()
plt.show()

# %% [markdown]
# 0 	airplane
# 1 	automobile
# 2 	bird
# 3 	cat
# 4 	deer
# 5 	dog
# 6 	frog
# 7 	horse
# 8 	ship
# 9 	truck

# %%
x = x_test
y = model(x)
start = 5000

for k in range(10):
    plt.figure(figsize=(8, 2))
    plt.subplot(1,2,1)
    plt.imshow(x[start+k].reshape((32, 32, 3)))
    ind = np.arange(0, 10)
    plt.subplot(1,2,2)
    plt.bar(ind, y[start+k].numpy().flatten())
    plt.xticks(range(10))
